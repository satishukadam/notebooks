# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np 
import datetime
from datetime import date
# %matplotlib inline

# %%
img1 = cv2.imread('D:/Study/DataScience/OpenCV/messi.jpg', cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
img2 = cv2.imread('D:/Study/DataScience/OpenCV/fifa.png', cv2.IMREAD_COLOR)
plt.imshow(img2)

# %%
img1_re = cv2.resize(img1, (800, 1000))
img2_re = cv2.resize(img2, (800, 1000))

# %%
plt.figure(figsize=(12,18))
merged = cv2.addWeighted(img1_re, 0.8, img2_re, 0.2, 0)
plt.imshow(merged)
