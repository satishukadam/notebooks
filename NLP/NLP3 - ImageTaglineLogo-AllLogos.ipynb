# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read image
image = cv2.imread("D:\Study\DataScience\OpenCV\messi.jpg")

# convert image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# font 
font = cv2.FONT_HERSHEY_SIMPLEX 

# fontScale 
fontScale = 2

# text to be placed on image
text = 'This is the tagline'
textsize = cv2.getTextSize(text, font, fontScale, 2)[0]

# origin 
org = (int((image.shape[1]-textsize[0])/2),int(image.shape[0]*15/100))
  
# Yellow font color in RGB 
color = (255,255,0) 
  
# Line thickness of 2 px 
thickness = 2
   
# Using cv2.putText() method 
tagged_image = cv2.putText(image, text, org, font, fontScale, color, thickness, cv2.LINE_AA)

# display tagged image
plt.figure(figsize=(10,12))
plt.imshow(tagged_image)

# save tagged image
# cv2.imwrite('/path/to/destination/image.png',image)

tagged_image.shape
# Out:
# (687, 1200, 3)

# %%
logo = cv2.imread("D:\Study\DataScience\OpenCV\logo.jpg")
logo = cv2.cvtColor(logo, cv2.COLOR_BGR2RGB)

logo = cv2.resize(logo, (160, 80))
plt.imshow(logo)

print(logo.shape)
# Out:
# (80, 160, 3)

# %%
tagged_image.shape
# Out:
# (687, 1200, 3)

# %%
# logo at top left corner
l_img = image
s_img = logo

x_offset = y_offset= 50

l_img[y_offset:y_offset+s_img.shape[0], x_offset:x_offset+s_img.shape[1]] = s_img

plt.figure(figsize=(10,12))
plt.imshow(l_img)

# %%
# logo at bottom left corner

l_img[l_img.shape[0]- s_img.shape[0]-y_offset:l_img.shape[0]-y_offset, x_offset:x_offset+s_img.shape[1]] = s_img

plt.figure(figsize=(10,12))
plt.imshow(l_img)

# %%
# logo at bottom right corner

l_img[l_img.shape[0]- s_img.shape[0]-y_offset:l_img.shape[0]-y_offset, l_img.shape[1]- s_img.shape[1]-x_offset:l_img.shape[1]-x_offset] = s_img

plt.figure(figsize=(10,12))
plt.imshow(l_img)

# %%
# logo at top right corner

l_img[y_offset:y_offset+s_img.shape[0], l_img.shape[1]- s_img.shape[1]-x_offset:l_img.shape[1]-x_offset] = s_img

plt.figure(figsize=(10,12))
plt.imshow(l_img)

# %%
# logo at bottom center

l_img[l_img.shape[0]-s_img.shape[0]-y_offset:l_img.shape[0]-y_offset,
      int(l_img.shape[1]-s_img.shape[1])//2:int(l_img.shape[1]-s_img.shape[1])//2 + s_img.shape[1]] = s_img

plt.figure(figsize=(10,12))
plt.imshow(l_img)
