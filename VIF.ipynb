# %%
#Imports
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

df = pd.read_csv('D:/Study/DataScience/LinearRegression/PolynomialRegression/winequality-red.csv')
df.dropna()
df = df._get_numeric_data() #drop non-numeric cols

A = df.copy()

# %%
def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1]))
    dropped = True
    while dropped:
        dropped = False
        vif = [variance_inflation_factor(X.iloc[:, variables].values, ix)
               for ix in range(X.iloc[:, variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X.iloc[:, variables].columns[maxloc] +
                  '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped = True

    print('Remaining variables:')
    print(X.columns[variables])
    return X.iloc[:, variables]

calculate_vif_(A)
# Out:
# dropping 'density' at index: 7
# dropping 'pH' at index: 7
# dropping 'alcohol' at index: 8
# dropping 'fixed acidity' at index: 0
# dropping 'quality' at index: 7
# dropping 'sulphates' at index: 6
# dropping 'free sulfur dioxide' at index: 4
# dropping 'volatile acidity' at index: 0
# Remaining variables:
# Index(['citric acid', 'residual sugar', 'chlorides', 'total sulfur dioxide'], dtype='object')
#       citric acid  residual sugar  chlorides  total sulfur dioxide
# 0            0.00             1.9      0.076                  34.0
# 1            0.00             2.6      0.098                  67.0
# 2            0.04             2.3      0.092                  54.0
# 3            0.56             1.9      0.075                  60.0
# 4            0.00             1.9      0.076                  34.0
# 5            0.00             1.8      0.075                  40.0
# 6            0.06             1.6      0.069                  59.0
# ...

# %%
v = pd.DataFrame()

v["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
v["features"] = X.columns

v
# Out:
#      VIF Factor              features
# 0     74.455312         fixed acidity
# 1     17.960867      volatile acidity
# 2      9.192549           citric acid
# 3      4.664003        residual sugar
# 4      6.641291             chlorides
# 5      6.460603   free sulfur dioxide
# 6      6.605274  total sulfur dioxide
# 7   1528.154302               density
# 8   1078.171089                    pH
# 9     22.462103             sulphates
# 10   147.616345               alcohol
# 11    77.728259               quality

# %%
v1 = variance_inflation_factor(X.values, 8)

print(v1)
# Out:
# 1078.1710892657966
